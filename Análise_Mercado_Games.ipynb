# %% [markdown]
# <a href="https://colab.research.google.com/github/rponeconsultoria/portfoliorp/blob/main/An%C3%A1lise_Mercado_Games.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Libs Essenciais

# Libs para modelagem e matrizes
import numpy as np
import pandas as pd

# Libs para análises
import matplotlib.pyplot as plt
import seaborn as sns

# Libs para ignorar avisos
import warnings

# Desabilitando os avisos
warnings.filterwarnings('ignore')

# %%
#Lendo o dataframe
Base_Dados = pd.read_csv('PS4_GamesSales.csv', encoding='latin-1')

#Verificando
Base_Dados.head()
# Out:
#                         Game    Year             Genre       Publisher  \
# 0         Grand Theft Auto V  2014.0            Action  Rockstar Games
# 1  Call of Duty: Black Ops 3  2015.0           Shooter      Activision
# 2      Red Dead Redemption 2  2018.0  Action-Adventure  Rockstar Games
# 3         Call of Duty: WWII  2017.0           Shooter      Activision
# 4                    FIFA 18  2017.0            Sports       EA Sports
#
#    North America  Europe  Japan  Rest of World  Global
# 0           6.06    9.71   0.60           3.02   19.39
# 1           6.18    6.05   0.41           2.44   15.09
# 2           5.26    6.21   0.21           2.26   13.94
# 3           4.67    6.21   0.40           2.12   13.40
# 4           1.27    8.64   0.15           1.73   11.80

# %%
#Dimensão do dataframe
Base_Dados.shape
# Out:
# (1034, 9)

# %%
#Chamando campos nulos
Base_Dados.isnull().sum()
# Out:
# Game               0
# Year             209
# Genre              0
# Publisher        209
# North America      0
# Europe             0
# Japan              0
# Rest of World      0
# Global             0
# dtype: int64

# %%
#Analisando de forma gráfica
plt.figure(figsize=(14,5))
plt.title('Analisando campos nulos')
sns.heatmap( Base_Dados.isnull())
# Out:
# <Axes: title={'center': 'Analisando campos nulos'}>

# %%
#Removendo valores nulos
Base_Dados.dropna( inplace=True)

# %%
#Estatísticas do DataFrame
Base_Dados.describe()
# Out:
#               Year  North America      Europe       Japan  Rest of World  \
# count   825.000000     825.000000  825.000000  825.000000     825.000000
# mean   2015.966061       0.256448    0.311600    0.042048       0.111552
# std       1.298360       0.620259    0.868271    0.119814       0.274713
# min    2013.000000       0.000000    0.000000    0.000000       0.000000
# 25%    2015.000000       0.000000    0.000000    0.000000       0.000000
# 50%    2016.000000       0.050000    0.020000    0.000000       0.020000
# 75%    2017.000000       0.190000    0.220000    0.040000       0.090000
# max    2020.000000       6.180000    9.710000    2.170000       3.020000
#
#            Global
# count  825.000000
# mean     0.721721
# std      1.743122
# min      0.000000
# 25%      0.030000
# 50%      0.120000
# 75%      0.560000
# max     19.390000

# %%
#Vendas globais ao longo dos anos

#Tamanho da imagem
plt.figure(figsize=(14,5))

#Título da imagem
plt.title('Quantidade de vendas Globais (mi)', loc='left', fontsize=14)

#Grafico
sns.barplot( data=Base_Dados, x='Year', y='Global', ci=None, color ='#69b3a2', estimator=sum)

#Label
plt.ylabel('Quantidade Vendas (mi)')
# Out:
# <ipython-input-36-395b6f4a71aa>:10: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot( data=Base_Dados, x='Year', y='Global', ci=None, color ='#69b3a2', estimator=sum)
# Text(0, 0.5, 'Quantidade Vendas (mi)')

# %%
#Retirar os anos de 2019 e 2020
Base_Dados= Base_Dados.loc[  (Base_Dados['Year'] !=2019) & (Base_Dados['Year'] !=2020) ]

#Verificar
Base_Dados.head()
# Out:
#                         Game    Year             Genre       Publisher  \
# 0         Grand Theft Auto V  2014.0            Action  Rockstar Games
# 1  Call of Duty: Black Ops 3  2015.0           Shooter      Activision
# 2      Red Dead Redemption 2  2018.0  Action-Adventure  Rockstar Games
# 3         Call of Duty: WWII  2017.0           Shooter      Activision
# 4                    FIFA 18  2017.0            Sports       EA Sports
#
#    North America  Europe  Japan  Rest of World  Global
# 0           6.06    9.71   0.60           3.02   19.39
# 1           6.18    6.05   0.41           2.44   15.09
# 2           5.26    6.21   0.21           2.26   13.94
# 3           4.67    6.21   0.40           2.12   13.40
# 4           1.27    8.64   0.15           1.73   11.80

# %%
#Tamanho
plt.figure( figsize=(12, 5) )

#Tamanho
plt.title( 'Distribuição das Vendas Globais')

#Estilo
plt.style.use('ggplot')

#Tamanho
plt.figure( figsize=(12, 5) )

#Tamanho
plt.title( 'Distribuição das Vendas Globais')

#Estilo
plt.style.use('ggplot')


#Gráfico de densidade
sns.kdeplot(Base_Dados['Global'], shade=True, bw=1, color='#96a8a8', linewidth=2.5);
# Out:
# <ipython-input-46-676ce90d159b>:21: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=1`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.14.0.
#
#   sns.kdeplot(Base_Dados['Global'], shade=True, bw=1, color='#96a8a8', linewidth=2.5);
# <ipython-input-46-676ce90d159b>:21: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(Base_Dados['Global'], shade=True, bw=1, color='#96a8a8', linewidth=2.5);

# %%
Base_Dados.groupby( by=['Year']).sum()
# Out:
#                                                      Game  \
# Year
# 2013.0  Call of Duty: GhostsBattlefield 4FIFA Soccer 1...
# 2014.0  Grand Theft Auto VCall of Duty: Advanced Warfa...
# 2015.0  Call of Duty: Black Ops 3Fallout 4FIFA 16Star ...
# 2016.0  FIFA 17Uncharted (PS4)Call of Duty: Infinite W...
# 2017.0  Call of Duty: WWIIFIFA 18Horizon: Zero DawnCra...
# 2018.0  Red Dead Redemption 2Spider-Man (PS4)God of Wa...
#
#                                                     Genre  \
# Year
# 2013.0  ShooterShooterSportsAction-AdventureShooterRac...
# 2014.0  ActionShooterAction-AdventureMiscSportsShooter...
# 2015.0  ShooterRole-PlayingSportsShooterActionRole-Pla...
# 2016.0  SportsActionShooterShooterRole-PlayingShooterS...
# 2017.0  ShooterSportsActionPlatformShooterShooterActio...
# 2018.0  Action-AdventureAction-AdventureActionActionAc...
#
#                                                 Publisher  North America  \
# Year
# ...

# %%
#Tamanho
plt.figure( figsize=(10, 4))

#Titulo
plt.title('Análise da distribuição mundial')

#Grafico

sns.boxplot( data=Base_Dados, x='Year', y='Global');

# %%
#Ranking de vendas
Base_Dados.loc[ Base_Dados['Global'] >=10]
# Out:
#                         Game    Year             Genre  \
# 0         Grand Theft Auto V  2014.0            Action
# 1  Call of Duty: Black Ops 3  2015.0           Shooter
# 2      Red Dead Redemption 2  2018.0  Action-Adventure
# 3         Call of Duty: WWII  2017.0           Shooter
# 4                    FIFA 18  2017.0            Sports
# 5                    FIFA 17  2016.0            Sports
# 6            Uncharted (PS4)  2016.0            Action
#
#                         Publisher  North America  Europe  Japan  \
# 0                  Rockstar Games           6.06    9.71   0.60
# 1                      Activision           6.18    6.05   0.41
# 2                  Rockstar Games           5.26    6.21   0.21
# 3                      Activision           4.67    6.21   0.40
# 4                       EA Sports           1.27    8.64   0.15
# 5                 Electronic Arts           1.26    7.95   0.12
# 6  Sony Interactive Entertainment           4.49    3.93   0.21
#
# ...

# %%
6.06 / 19.39, 9.71 / 19.39, 0.60 / 19.39, 3.02 / 19.39
# Out:
# (0.3125322331098504,
#  0.5007735946364106,
#  0.030943785456420833,
#  0.1557503867973182)

# %%
# Assumindo 'Base_Dados' como DataFrame
Analise = Base_Dados.groupby(by=['Year'])[['North America', 'Global']].sum()

#% de Países em relação ao valor Global
[America / Total * 100 for America, Total in zip(Analise['North America'], Analise['Global'])]
# Out:
# [35.9874826147427,
#  34.35476909797151,
#  37.01768788715576,
#  34.92484526967286,
#  34.20168067226891,
#  39.14342629482071]

# %%
Analise
# Out:
#         North America  Global
# Year
# 2013.0          10.35   28.76
# 2014.0          39.80  115.85
# 2015.0          49.60  133.99
# 2016.0          47.40  135.72
# 2017.0          44.77  130.90
# 2018.0          19.65   50.20

# %%
# Recalculando 'Analise'

Analise = Base_Dados.groupby(by=['Year'])[['North America', 'Europe', 'Japan', 'Rest of World', 'Global']].sum()

#Analisando a proporção dos 100% de cada continente comparado ao total

America =[America / Total * 100 for America, Total in zip(Analise['North America'], Analise['Global'] ) ]
Europa =[Europa / Total * 100 for Europa, Total in zip(Analise['Europe'], Analise['Global'] ) ]
Japao =[Japao / Total * 100 for Japao, Total in zip(Analise['Japan'], Analise['Global'] ) ]
Mundo =[Mundo / Total * 100 for Mundo, Total in zip(Analise['Rest of World'], Analise['Global'] ) ]

America, Europa, Japao, Mundo
# Out:
# ([35.9874826147427,
#   34.35476909797151,
#   37.01768788715576,
#   34.92484526967286,
#   34.20168067226891,
#   39.14342629482071],
#  [44.78442280945759,
#   46.71558049201555,
#   41.95089185760131,
#   42.72030651340996,
#   43.68220015278838,
#   37.25099601593625],
#  [3.372739916550765,
#   3.0902028485110056,
#   5.433241286663184,
#   7.110226937813145,
#   6.936592818945759,
#   8.227091633466136],
#  [15.890125173852576,
#   15.78765645230902,
#   15.58325248152847,
#   15.259357500736812,
#   15.194805194805195,
#   15.31872509960159])

# %%
# Gráfico de % de Países em relação ao valor Global

#Tamanho
plt.figure( figsize=(10,5))

# Gráfico de % de Países em relação ao valor Global

#Tamanho
plt.figure(figsize=(10, 5))

#Largura da barra
Largura_Barra = 0.85

# Acessando o index do DataFrame
Rotulos = Analise.index
Grupos = ['America', 'Europa', 'Japao', 'Mundo']

# Criando um DataFrame para facilitar o plot
df_plot = pd.DataFrame({'America': America, 'Europa': Europa, 'Japao': Japao, 'Mundo': Mundo}, index=Rotulos)

# Plotando os dados
df_plot.plot(kind='bar', width=Largura_Barra)

# Titulo
plt.title('Análise de distribuição por continente')
plt.xlabel('Ano')
plt.ylabel('Porcentagem (%)')
plt.xticks(rotation=0)  # Para evitar a rotação dos rótulos do eixo x

plt.show()

# %%
Base_Dados.head()
# Out:
#                         Game    Year             Genre       Publisher  \
# 0         Grand Theft Auto V  2014.0            Action  Rockstar Games
# 1  Call of Duty: Black Ops 3  2015.0           Shooter      Activision
# 2      Red Dead Redemption 2  2018.0  Action-Adventure  Rockstar Games
# 3         Call of Duty: WWII  2017.0           Shooter      Activision
# 4                    FIFA 18  2017.0            Sports       EA Sports
#
#    North America  Europe  Japan  Rest of World  Global
# 0           6.06    9.71   0.60           3.02   19.39
# 1           6.18    6.05   0.41           2.44   15.09
# 2           5.26    6.21   0.21           2.26   13.94
# 3           4.67    6.21   0.40           2.12   13.40
# 4           1.27    8.64   0.15           1.73   11.80

# %%
Base_Dados['Publisher'].unique()
# Out:
# array(['Rockstar Games', 'Activision', 'EA Sports', 'Electronic Arts',
#        'Sony Interactive Entertainment', 'Bethesda Softworks',
#        'Sony Computer Entertainment', 'Namco Bandai Games', 'Square Enix',
#        'Capcom', 'Blizzard Entertainment', 'Ubisoft',
#        'Warner Bros. Interactive', '2K Sports',
#        'Warner Bros. Interactive Entertainment',
#        'Konami Digital Entertainment', '2K Games', 'Hello Games',
#        '505 Games', 'Deep Silver', 'Take-Two Interactive',
#        'Bandai Namco Games', 'Sega', 'Tecmo Koei', 'Gearbox Software',
#        'Mojang', 'Disney Interactive Studios', 'Focus Home Interactive',
#        'Studio Wildcard', 'Codemasters', 'Koch Media',
#        'Harmonix Music Systems', 'Rebellion Developments', 'Gun Media',
#        'Telltale Games', 'Kalypso Media', 'City Interactive',
#        'NIS America', 'Sold Out', 'Tripwire Interactive', 'PQube',
#        'THQ Nordic', 'Milestone S.r.l.', 'Nordic Games', 'Astragon',
# ...

# %%
sns.boxplot( data=Base_Dados, x='Publisher', y='Global');

# %%
#Observe que este gráfico é difícil de se intepretar, vamos transformar valores quantitativos em qualitativos!

from sklearn.preprocessing import LabelEncoder

Funcao_Label = LabelEncoder()

Base_Dados['Produtor'] =Funcao_Label.fit_transform(Base_Dados['Publisher'])
Base_Dados['Gênero'] =Funcao_Label.fit_transform(Base_Dados['Genre'])
Base_Dados['Jogo'] = Funcao_Label.fit_transform(Base_Dados['Game'])


Base_Dados.head()

#Esta função pega todos os itens de Publishers e os transforma em numeros
# Out:
# <ipython-input-92-8962ccc0c08c>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Base_Dados['Produtor'] =Funcao_Label.fit_transform(Base_Dados['Publisher'])
# <ipython-input-92-8962ccc0c08c>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Base_Dados['Gênero'] =Funcao_Label.fit_transform(Base_Dados['Genre'])
# <ipython-input-92-8962ccc0c08c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
Paleta_Cores =sns.color_palette('Dark2',8)
Paleta_Cores
# Out:
# [(0.10588235294117647, 0.6196078431372549, 0.4666666666666667),
#  (0.8509803921568627, 0.37254901960784315, 0.00784313725490196),
#  (0.4588235294117647, 0.4392156862745098, 0.7019607843137254),
#  (0.9058823529411765, 0.1607843137254902, 0.5411764705882353),
#  (0.4, 0.6509803921568628, 0.11764705882352941),
#  (0.9019607843137255, 0.6705882352941176, 0.00784313725490196),
#  (0.6509803921568628, 0.4627450980392157, 0.11372549019607843),
#  (0.4, 0.4, 0.4)]

# %%
plt.title= ('Analise de vendas dos produtores de Games (mi)')
sns.scatterplot( data=Base_Dados, x='Produtor', y='Global', color=Paleta_Cores[0])
# Out:
# <Axes: xlabel='Produtor', ylabel='Global'>

# %%
plt.title= ('Analise de vendas dos gêneros de Games (mi)')
sns.scatterplot( data=Base_Dados, x='Gênero', y='Global', color=Paleta_Cores[0])
# Out:
# <Axes: xlabel='Gênero', ylabel='Global'>

# %%
plt.title= ('Analise de vendas dos Games (mi)')
sns.scatterplot( data=Base_Dados, x='Jogo', y='Global', color=Paleta_Cores[0])
# Out:
# <Axes: xlabel='Jogo', ylabel='Global'>
